# %%
from cassandra.cluster import Cluster
import csv
import uuid


def fetch_data_from_cassandra():
    
    cluster = Cluster(["localhost"])
    session = cluster.connect()
    session.set_keyspace('customer_contract_management')

    
    rows_query = "SELECT COUNT(*) FROM clients"
    rows_count = session.execute(rows_query).one()[0]

    
    if rows_count > 100:
        fetch_limit = 50
    elif rows_count > 50:
        fetch_limit = 20
    else:
        fetch_limit = rows_count

    
    query = """
        SELECT client_id, name, address, contact_number, 
               area_type_id, classification_id, client_status_id
        FROM clients
        LIMIT %s
    """
    clients = session.execute(query, [fetch_limit])
    clients = list(clients)  

    
    area_types_query = """
        SELECT area_type_id, area_type, description FROM area_types
    """
    area_types = session.execute(area_types_query)
    area_types = list(area_types)  

    
    classifications_query = """
        SELECT classification_id, classification, description FROM classifications
    """
    classifications = session.execute(classifications_query)
    classifications = list(classifications)  
    client_statuses_query = """
        SELECT client_status_id, account_status, description FROM client_statuses
    """
    client_statuses = session.execute(client_statuses_query)
    client_statuses = list(client_statuses)  
    contracts_query = """
        SELECT contract_id, client_id, area_type_id, contract_type_id, start_date, end_date,
               status_id, base_fee, last_updated, reason_for_status
        FROM contracts
        LIMIT %s
    """
    contracts = session.execute(contracts_query, [fetch_limit])
    contracts = list(contracts)  
    contract_statuses_query = """
        SELECT status_id, status, description FROM contract_statuses
    """
    contract_statuses = session.execute(contract_statuses_query)
    contract_statuses = list(contract_statuses)  
    contract_policies_query = """
        SELECT contract_id, policy_id FROM contract_policies
        LIMIT %s
    """
    contract_policies = session.execute(contract_policies_query, [fetch_limit])
    contract_policies = list(contract_policies)  
    policies_query = """
        SELECT policy_id, policy_name, policy_details, effective_date
        FROM regulatory_policies
    """
    policies = session.execute(policies_query)
    policies = list(policies)  

    return clients, area_types, classifications, client_statuses, contracts, contract_statuses, contract_policies, policies



def merge_and_export_to_csv():
    # Fetch data from Cassandra
    clients, area_types, classifications, client_statuses, contracts, contract_statuses, contract_policies, policies = fetch_data_from_cassandra()

    # Create dictionaries for quick lookups
    area_types_dict = {at.area_type_id: at for at in area_types}
    classifications_dict = {cl.classification_id: cl for cl in classifications}
    client_statuses_dict = {cs.client_status_id: cs for cs in client_statuses}
    contract_statuses_dict = {cs.status_id: cs for cs in contract_statuses}
    policies_dict = {policy.policy_id: policy for policy in policies}

    # Create a list for merged rows
    merged_rows = []

    # Merge data from Clients, Contracts, Contract Policies, and Policies
    for client in clients:
        # Get the related area type, classification, and client status for this client
        area_type = area_types_dict.get(client.area_type_id)
        classification = classifications_dict.get(client.classification_id)
        client_status = client_statuses_dict.get(client.client_status_id)

        # Check if the related records exist
        if area_type and classification and client_status:
            print(f"Merging client: {client.client_id}")
        else:
            print(f"Skipping client: {client.client_id} - Missing related data")
        # Find the related contracts for this client
        client_contracts = [
            contract for contract in contracts if contract.client_id == client.client_id]

        for contract in client_contracts:
            # Get the related contract status for this contract
            contract_status = contract_statuses_dict.get(contract.status_id)

            # Find related contract policies for this contract
            related_policies = [
                cp for cp in contract_policies if cp.contract_id == contract.contract_id]

            # Merge each contract with the related policies
            for cp in related_policies:
                policy = policies_dict.get(cp.policy_id)

                # Merge client, contract, and policy data
                merged_rows.append([
                    client.client_id, client.name, client.address, client.contact_number,
                    area_type.area_type if area_type else "Unknown", area_type.description if area_type else "Unknown",
                    classification.classification if classification else "Unknown", classification.description if classification else "Unknown",
                    client_status.account_status if client_status else "Unknown", client_status.description if client_status else "Unknown",
                    contract.contract_id, contract.start_date, contract.end_date, contract.base_fee, contract.last_updated,
                    contract_status.status if contract_status else "Unknown", contract_status.description if contract_status else "Unknown",
                    policy.policy_name if policy else "Unknown", policy.policy_details if policy else "Unknown", policy.effective_date if policy else "Unknown"
                ])

    # Write merged data to a CSV file
    with open('merged_cassandra.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header row
        writer.writerow([
            "ClientID", "ClientName", "Address", "ContactNumber", "AreaType", "AreaDescription",
            "Classification", "ClassificationDescription", "AccountStatus", "StatusDescription",
            "ContractID", "StartDate", "EndDate", "BaseFee", "LastUpdated", "ContractStatus",
            "ContractStatusDescription", "PolicyName", "PolicyDetails", "EffectiveDate"
        ])

        # Write merged rows
        for row in merged_rows:
            writer.writerow(row)

    print("CSV file 'merged_cassandra.csv' has been created successfully!")


if __name__ == "__main__":
    merge_and_export_to_csv()

# %%
from cassandra.cluster import Cluster
import csv
import uuid


def fetch_data_from_cassandra():
    # Connect to Cassandra
    cluster = Cluster(["localhost"])
    session = cluster.connect()
    session.set_keyspace('customer_contract_management')

    # Fetch the number of rows in the clients table
    rows_query = "SELECT COUNT(*) FROM clients"
    rows_count = session.execute(rows_query).one()[0]

    # Determine fetch limit
    if rows_count > 100:
        fetch_limit = 50
    elif rows_count > 50:
        fetch_limit = 20
    else:
        fetch_limit = rows_count

    # Fetch data from the clients table (without aliases)
    query = """
        SELECT client_id, name, address, contact_number, 
               area_type_id, classification_id, client_status_id
        FROM clients
        LIMIT %s
    """
    clients = session.execute(query, [fetch_limit])
    clients = list(clients)  # Convert to list

    # Fetch data from the area_types table (without aliases)
    area_types_query = """
        SELECT area_type_id, area_type, description FROM area_types
    """
    area_types = session.execute(area_types_query)
    area_types = list(area_types)  # Convert to list

    # Fetch data from the classifications table (without aliases)
    classifications_query = """
        SELECT classification_id, classification, description FROM classifications
    """
    classifications = session.execute(classifications_query)
    classifications = list(classifications)  # Convert to list

    # Fetch data from the client_statuses table (without aliases)
    client_statuses_query = """
        SELECT client_status_id, account_status, description FROM client_statuses
    """
    client_statuses = session.execute(client_statuses_query)
    client_statuses = list(client_statuses)  # Convert to list

    # Fetch Contracts data (without aliases)
    contracts_query = """
        SELECT contract_id, client_id, area_type_id, contract_type_id, start_date, end_date,
               status_id, base_fee, last_updated, reason_for_status
        FROM contracts
        LIMIT %s
    """
    contracts = session.execute(contracts_query, [fetch_limit])
    contracts = list(contracts)  # Convert to list

    # Fetch Contract Statuses (without aliases)
    contract_statuses_query = """
        SELECT status_id, status, description FROM contract_statuses
    """
    contract_statuses = session.execute(contract_statuses_query)
    contract_statuses = list(contract_statuses)  # Convert to list

    # Fetch Contract Policies data separately (without aliases)
    contract_policies_query = """
        SELECT contract_id, policy_id FROM contract_policies
        LIMIT %s
    """
    contract_policies = session.execute(contract_policies_query, [fetch_limit])
    contract_policies = list(contract_policies)  # Convert to list

    # Fetch Regulatory Policies (without aliases)
    policies_query = """
        SELECT policy_id, policy_name, policy_details, effective_date
        FROM regulatory_policies
    """
    policies = session.execute(policies_query)
    policies = list(policies)  # Convert to list

    return clients, area_types, classifications, client_statuses, contracts, contract_statuses, contract_policies, policies


def merge_and_export_to_csv():
    # Fetch data from Cassandra
    clients, area_types, classifications, client_statuses, contracts, contract_statuses, contract_policies, policies = fetch_data_from_cassandra()

    # Debugging: print number of clients and contracts fetched
    print(f"Fetched {len(clients)} clients from the database.")
    print(f"Fetched {len(contracts)} contracts from the database.")

    # Create dictionaries for quick lookups
    area_types_dict = {at.area_type_id: at for at in area_types}
    classifications_dict = {cl.classification_id: cl for cl in classifications}
    client_statuses_dict = {cs.client_status_id: cs for cs in client_statuses}
    contract_statuses_dict = {cs.status_id: cs for cs in contract_statuses}
    policies_dict = {policy.policy_id: policy for policy in policies}

    # Create a list for merged rows
    merged_rows = []

    # Merge data from Clients, Contracts, Contract Policies, and Policies
    for client in clients:
        print(f"Merging client: {client.client_id}")

        # Get the related area type, classification, and client status for this client
        area_type = area_types_dict.get(client.area_type_id)
        classification = classifications_dict.get(client.classification_id)
        client_status = client_statuses_dict.get(client.client_status_id)

        # Check if the related records exist
        if area_type and classification and client_status:
            print(f"Found related data for client: {client.client_id}")
        else:
            print(f"Skipping client {client.client_id} - Missing related data")

        # Find the related contracts for this client
        client_contracts = [
            contract for contract in contracts if contract.client_id == client.client_id
        ]

        # Debugging: Check the number of contracts found for the client
        print(f"Client {client.client_id} has {len(client_contracts)} contracts")

        # If no contracts were found, skip to the next client
        if len(client_contracts) == 0:
            print(f"No contracts found for client {client.client_id}. Skipping.")
            continue

        for contract in client_contracts:
            # Debugging: Check the contract data
            print(f"Found contract {contract.contract_id} for client {client.client_id}")

            # Get the related contract status for this contract
            contract_status = contract_statuses_dict.get(contract.status_id)

            # Find related contract policies for this contract
            related_policies = [
                cp for cp in contract_policies if cp.contract_id == contract.contract_id
            ]

            # Debugging: Check number of policies for this contract
            print(f"Found {len(related_policies)} policies for contract {contract.contract_id}")

            # Merge each contract with the related policies
            for cp in related_policies:
                policy = policies_dict.get(cp.policy_id)

                # Merge client, contract, and policy data
                merged_rows.append([
                    client.client_id, client.name, client.address, client.contact_number,
                    area_type.area_type if area_type else "Unknown", area_type.description if area_type else "Unknown",
                    classification.classification if classification else "Unknown", classification.description if classification else "Unknown",
                    client_status.account_status if client_status else "Unknown", client_status.description if client_status else "Unknown",
                    contract.contract_id, contract.start_date, contract.end_date, contract.base_fee, contract.last_updated,
                    contract_status.status if contract_status else "Unknown", contract_status.description if contract_status else "Unknown",
                    policy.policy_name if policy else "Unknown", policy.policy_details if policy else "Unknown", policy.effective_date if policy else "Unknown"
                ])

    # Write merged data to a CSV file
    with open('merged_cassandra.csv', mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header row
        writer.writerow([
            "ClientID", "ClientName", "Address", "ContactNumber", "AreaType", "AreaDescription",
            "Classification", "ClassificationDescription", "AccountStatus", "StatusDescription",
            "ContractID", "StartDate", "EndDate", "BaseFee", "LastUpdated", "ContractStatus",
            "ContractStatusDescription", "PolicyName", "PolicyDetails", "EffectiveDate"
        ])

        # Write merged rows
        for row in merged_rows:
            writer.writerow(row)

    print(f"CSV file 'merged_cassandra.csv' has been created successfully with {len(merged_rows)} rows!")



if __name__ == "__main__":
    merge_and_export_to_csv()
# Out:
# Fetched 50 clients from the database.
# Fetched 50 contracts from the database.
# Merging client: 7f8b83a9-d6c2-4309-b6c7-8b4ae8cd40ec
# Found related data for client: 7f8b83a9-d6c2-4309-b6c7-8b4ae8cd40ec
# Client 7f8b83a9-d6c2-4309-b6c7-8b4ae8cd40ec has 0 contracts
# No contracts found for client 7f8b83a9-d6c2-4309-b6c7-8b4ae8cd40ec. Skipping.
# Merging client: 75ad2f97-c1bc-49e5-ad6b-8681a0b143c9
# Found related data for client: 75ad2f97-c1bc-49e5-ad6b-8681a0b143c9
# Client 75ad2f97-c1bc-49e5-ad6b-8681a0b143c9 has 0 contracts
# No contracts found for client 75ad2f97-c1bc-49e5-ad6b-8681a0b143c9. Skipping.
# Merging client: dbe08fa5-9281-4a14-b2a6-48abf1a6d7d3
# Found related data for client: dbe08fa5-9281-4a14-b2a6-48abf1a6d7d3
# Client dbe08fa5-9281-4a14-b2a6-48abf1a6d7d3 has 0 contracts
# No contracts found for client dbe08fa5-9281-4a14-b2a6-48abf1a6d7d3. Skipping.
# Merging client: ea614ade-9cee-43ba-bb90-319f7079f8dc
# Found related data for client: ea614ade-9cee-43ba-bb90-319f7079f8dc
# Client ea614ade-9cee-43ba-bb90-319f7079f8dc has 1 contracts
# Found contract 15b3f64a-d57e-4517-8e48-8faef8724db1 for client ea614ade-9cee-43ba-bb90-319f7079f8dc
# Found 3 policies for contract 15b3f64a-d57e-4517-8e48-8faef8724db1
# Merging client: 1496d69a-c556-484b-8b05-90dbe734443a
# Found related data for client: 1496d69a-c556-484b-8b05-90dbe734443a
# Client 1496d69a-c556-484b-8b05-90dbe734443a has 0 contracts
# No contracts found for client 1496d69a-c556-484b-8b05-90dbe734443a. Skipping.
# Merging client: 38e0e484-d265-4ceb-9053-95234910aa5a
# Found related data for client: 38e0e484-d265-4ceb-9053-95234910aa5a
# Client 38e0e484-d265-4ceb-9053-95234910aa5a has 0 contracts
# No contracts found for client 38e0e484-d265-4ceb-9053-95234910aa5a. Skipping.
# Merging client: ebe822f1-d96b-41e2-93c5-ffec612819de
# Found related data for client: ebe822f1-d96b-41e2-93c5-ffec612819de
# Client ebe822f1-d96b-41e2-93c5-ffec612819de has 0 contracts
# No contracts found for client ebe822f1-d96b-41e2-93c5-ffec612819de. Skipping.
# Merging client: f66d913a-5aba-4766-85f2-fbf6675c2bf7
# Found related data for client: f66d913a-5aba-4766-85f2-fbf6675c2bf7
# Client f66d913a-5aba-4766-85f2-fbf6675c2bf7 has 0 contracts
# No contracts found for client f66d913a-5aba-4766-85f2-fbf6675c2bf7. Skipping.
# Merging client: 18d85d82-a125-437c-8f3d-25f1f1b22268
# Found related data for client: 18d85d82-a125-437c-8f3d-25f1f1b22268
# Client 18d85d82-a125-437c-8f3d-25f1f1b22268 has 0 contracts
# No contracts found for client 18d85d82-a125-437c-8f3d-25f1f1b22268. Skipping.
# Merging client: 28e7666d-fdb9-43e6-b73e-4248e7d65135
# Found related data for client: 28e7666d-fdb9-43e6-b73e-4248e7d65135
# Client 28e7666d-fdb9-43e6-b73e-4248e7d65135 has 0 contracts
# No contracts found for client 28e7666d-fdb9-43e6-b73e-4248e7d65135. Skipping.
# Merging client: a25eb5e8-c514-4756-ab18-3a87cef66785
# Found related data for client: a25eb5e8-c514-4756-ab18-3a87cef66785
# Client a25eb5e8-c514-4756-ab18-3a87cef66785 has 0 contracts
# No contracts found for client a25eb5e8-c514-4756-ab18-3a87cef66785. Skipping.
# Merging client: cd5dedea-7a27-4960-ba98-0c46ab061444
# Found related data for client: cd5dedea-7a27-4960-ba98-0c46ab061444
# Client cd5dedea-7a27-4960-ba98-0c46ab061444 has 0 contracts
# No contracts found for client cd5dedea-7a27-4960-ba98-0c46ab061444. Skipping.
# Merging client: 27b6ef06-3087-47c8-a0d1-6e3b8d3cbfc8
# Found related data for client: 27b6ef06-3087-47c8-a0d1-6e3b8d3cbfc8
# Client 27b6ef06-3087-47c8-a0d1-6e3b8d3cbfc8 has 1 contracts
# Found contract aefa1648-f648-41d7-87f1-c44ffce1c030 for client 27b6ef06-3087-47c8-a0d1-6e3b8d3cbfc8
# Found 0 policies for contract aefa1648-f648-41d7-87f1-c44ffce1c030
# Merging client: 8cdb373b-1d22-4900-98c0-e854a50380ad
# Found related data for client: 8cdb373b-1d22-4900-98c0-e854a50380ad
# Client 8cdb373b-1d22-4900-98c0-e854a50380ad has 0 contracts
# No contracts found for client 8cdb373b-1d22-4900-98c0-e854a50380ad. Skipping.
# Merging client: 8b390027-1a9c-441f-8a20-1e74feb2d489
# Found related data for client: 8b390027-1a9c-441f-8a20-1e74feb2d489
# Client 8b390027-1a9c-441f-8a20-1e74feb2d489 has 0 contracts
# No contracts found for client 8b390027-1a9c-441f-8a20-1e74feb2d489. Skipping.
# Merging client: 44257f90-1a69-4bb9-b5c9-229d80a8f3b2
# Found related data for client: 44257f90-1a69-4bb9-b5c9-229d80a8f3b2
# Client 44257f90-1a69-4bb9-b5c9-229d80a8f3b2 has 0 contracts
# No contracts found for client 44257f90-1a69-4bb9-b5c9-229d80a8f3b2. Skipping.
# Merging client: 23660c82-110a-47e7-855c-9aec5743702c
# Found related data for client: 23660c82-110a-47e7-855c-9aec5743702c
# Client 23660c82-110a-47e7-855c-9aec5743702c has 0 contracts
# No contracts found for client 23660c82-110a-47e7-855c-9aec5743702c. Skipping.
# Merging client: a792cd21-f136-4151-af9a-e9682a19b95b
# Found related data for client: a792cd21-f136-4151-af9a-e9682a19b95b
# Client a792cd21-f136-4151-af9a-e9682a19b95b has 1 contracts
# Found contract 147ca877-4556-499e-a18d-9d38ff318e39 for client a792cd21-f136-4151-af9a-e9682a19b95b
# Found 0 policies for contract 147ca877-4556-499e-a18d-9d38ff318e39
# Merging client: 10e6b639-f251-4530-84cd-2202e80c2064
# Found related data for client: 10e6b639-f251-4530-84cd-2202e80c2064
# Client 10e6b639-f251-4530-84cd-2202e80c2064 has 0 contracts
# No contracts found for client 10e6b639-f251-4530-84cd-2202e80c2064. Skipping.
# Merging client: 803a0e07-deda-409a-a19b-70deae0250e9
# Found related data for client: 803a0e07-deda-409a-a19b-70deae0250e9
# Client 803a0e07-deda-409a-a19b-70deae0250e9 has 0 contracts
# No contracts found for client 803a0e07-deda-409a-a19b-70deae0250e9. Skipping.
# Merging client: e250ea13-3bfa-4e41-ab2c-b24c4a286db2
# Found related data for client: e250ea13-3bfa-4e41-ab2c-b24c4a286db2
# Client e250ea13-3bfa-4e41-ab2c-b24c4a286db2 has 0 contracts
# No contracts found for client e250ea13-3bfa-4e41-ab2c-b24c4a286db2. Skipping.
# Merging client: 087422b0-344e-44c9-97f5-f3b375a1c402
# Found related data for client: 087422b0-344e-44c9-97f5-f3b375a1c402
# Client 087422b0-344e-44c9-97f5-f3b375a1c402 has 1 contracts
# Found contract 935e0b3b-9256-437b-8ac8-645482cfc424 for client 087422b0-344e-44c9-97f5-f3b375a1c402
# Found 0 policies for contract 935e0b3b-9256-437b-8ac8-645482cfc424
# Merging client: 73688418-9121-4b41-bc92-0a14a9b060ed
# Found related data for client: 73688418-9121-4b41-bc92-0a14a9b060ed
# Client 73688418-9121-4b41-bc92-0a14a9b060ed has 1 contracts
# Found contract 92dcc6ec-9442-415d-95c3-951a5572e926 for client 73688418-9121-4b41-bc92-0a14a9b060ed
# Found 3 policies for contract 92dcc6ec-9442-415d-95c3-951a5572e926
# Merging client: 952f5f11-27c8-47e0-a60b-53277c53409d
# Found related data for client: 952f5f11-27c8-47e0-a60b-53277c53409d
# Client 952f5f11-27c8-47e0-a60b-53277c53409d has 1 contracts
# Found contract 003241ea-b118-476a-9117-537696bb5a8d for client 952f5f11-27c8-47e0-a60b-53277c53409d
# Found 0 policies for contract 003241ea-b118-476a-9117-537696bb5a8d
# Merging client: cbe16970-d339-4d92-ac04-c56c19e2a8b7
# Found related data for client: cbe16970-d339-4d92-ac04-c56c19e2a8b7
# Client cbe16970-d339-4d92-ac04-c56c19e2a8b7 has 0 contracts
# No contracts found for client cbe16970-d339-4d92-ac04-c56c19e2a8b7. Skipping.
# Merging client: 590f472b-ddc9-4656-bc85-def780fe6528
# Found related data for client: 590f472b-ddc9-4656-bc85-def780fe6528
# Client 590f472b-ddc9-4656-bc85-def780fe6528 has 0 contracts
# No contracts found for client 590f472b-ddc9-4656-bc85-def780fe6528. Skipping.
# Merging client: 1206a7a3-142b-4884-80f9-b0a7a142355c
# Found related data for client: 1206a7a3-142b-4884-80f9-b0a7a142355c
# Client 1206a7a3-142b-4884-80f9-b0a7a142355c has 0 contracts
# No contracts found for client 1206a7a3-142b-4884-80f9-b0a7a142355c. Skipping.
# Merging client: 6f5fb6af-38aa-4dcf-a80d-f760e9fa4f55
# Found related data for client: 6f5fb6af-38aa-4dcf-a80d-f760e9fa4f55
# Client 6f5fb6af-38aa-4dcf-a80d-f760e9fa4f55 has 1 contracts
# Found contract 154eb3a2-a742-4121-a42a-9a972c8ce55d for client 6f5fb6af-38aa-4dcf-a80d-f760e9fa4f55
# Found 3 policies for contract 154eb3a2-a742-4121-a42a-9a972c8ce55d
# Merging client: 84a23add-fa27-47dc-ba0d-4f6c529cfb22
# Found related data for client: 84a23add-fa27-47dc-ba0d-4f6c529cfb22
# Client 84a23add-fa27-47dc-ba0d-4f6c529cfb22 has 1 contracts
# Found contract c3653da1-78c2-42b4-8ada-8676f9f65c64 for client 84a23add-fa27-47dc-ba0d-4f6c529cfb22
# Found 3 policies for contract c3653da1-78c2-42b4-8ada-8676f9f65c64
# Merging client: e45014c9-8955-4a30-84f2-663954e33d46
# Found related data for client: e45014c9-8955-4a30-84f2-663954e33d46
# Client e45014c9-8955-4a30-84f2-663954e33d46 has 0 contracts
# No contracts found for client e45014c9-8955-4a30-84f2-663954e33d46. Skipping.
# Merging client: e61946ea-9120-472f-b1f1-e3a28f4eb695
# Found related data for client: e61946ea-9120-472f-b1f1-e3a28f4eb695
# Client e61946ea-9120-472f-b1f1-e3a28f4eb695 has 1 contracts
# Found contract b171bc04-c170-4638-b18a-e9e2ec6443c0 for client e61946ea-9120-472f-b1f1-e3a28f4eb695
# Found 0 policies for contract b171bc04-c170-4638-b18a-e9e2ec6443c0
# Merging client: e990013b-9a70-48a0-ab04-fa022db5810f
# Found related data for client: e990013b-9a70-48a0-ab04-fa022db5810f
# Client e990013b-9a70-48a0-ab04-fa022db5810f has 0 contracts
# No contracts found for client e990013b-9a70-48a0-ab04-fa022db5810f. Skipping.
# Merging client: fa7273db-8b1f-474c-b2a6-6755ea55b778
# Found related data for client: fa7273db-8b1f-474c-b2a6-6755ea55b778
# Client fa7273db-8b1f-474c-b2a6-6755ea55b778 has 0 contracts
# No contracts found for client fa7273db-8b1f-474c-b2a6-6755ea55b778. Skipping.
# Merging client: c24defff-9a5a-415a-8880-a1bb6cbb6d0d
# Found related data for client: c24defff-9a5a-415a-8880-a1bb6cbb6d0d
# Client c24defff-9a5a-415a-8880-a1bb6cbb6d0d has 0 contracts
# No contracts found for client c24defff-9a5a-415a-8880-a1bb6cbb6d0d. Skipping.
# Merging client: ed48775c-596a-45e8-bb09-7f4020c50dd3
# Found related data for client: ed48775c-596a-45e8-bb09-7f4020c50dd3
# Client ed48775c-596a-45e8-bb09-7f4020c50dd3 has 0 contracts
# No contracts found for client ed48775c-596a-45e8-bb09-7f4020c50dd3. Skipping.
# Merging client: ca52df4a-92c5-43f9-867e-6173b6e50f9f
# Found related data for client: ca52df4a-92c5-43f9-867e-6173b6e50f9f
# Client ca52df4a-92c5-43f9-867e-6173b6e50f9f has 0 contracts
# No contracts found for client ca52df4a-92c5-43f9-867e-6173b6e50f9f. Skipping.
# Merging client: d6742528-6776-4dd2-b768-22b81eb686bd
# Found related data for client: d6742528-6776-4dd2-b768-22b81eb686bd
# Client d6742528-6776-4dd2-b768-22b81eb686bd has 0 contracts
# No contracts found for client d6742528-6776-4dd2-b768-22b81eb686bd. Skipping.
# Merging client: 89e16387-15e9-4c8a-88e5-599868799e9d
# Found related data for client: 89e16387-15e9-4c8a-88e5-599868799e9d
# Client 89e16387-15e9-4c8a-88e5-599868799e9d has 0 contracts
# No contracts found for client 89e16387-15e9-4c8a-88e5-599868799e9d. Skipping.
# Merging client: dacdf276-06b3-4af8-a85a-eece893ead8a
# Found related data for client: dacdf276-06b3-4af8-a85a-eece893ead8a
# Client dacdf276-06b3-4af8-a85a-eece893ead8a has 1 contracts
# Found contract 9977ddd9-050a-44db-91f0-e666dbb07850 for client dacdf276-06b3-4af8-a85a-eece893ead8a
# Found 0 policies for contract 9977ddd9-050a-44db-91f0-e666dbb07850
# Merging client: d8467219-7130-4806-aebb-38fc02b349dc
# Found related data for client: d8467219-7130-4806-aebb-38fc02b349dc
# Client d8467219-7130-4806-aebb-38fc02b349dc has 0 contracts
# No contracts found for client d8467219-7130-4806-aebb-38fc02b349dc. Skipping.
# Merging client: f1fec459-f4d8-4cb7-872f-c801687ef682
# Found related data for client: f1fec459-f4d8-4cb7-872f-c801687ef682
# Client f1fec459-f4d8-4cb7-872f-c801687ef682 has 1 contracts
# Found contract acc58cf1-df0f-441e-893d-937189138f44 for client f1fec459-f4d8-4cb7-872f-c801687ef682
# Found 3 policies for contract acc58cf1-df0f-441e-893d-937189138f44
# Merging client: d35587f4-e5ab-4390-bbe9-7e499a51fc43
# Found related data for client: d35587f4-e5ab-4390-bbe9-7e499a51fc43
# Client d35587f4-e5ab-4390-bbe9-7e499a51fc43 has 0 contracts
# No contracts found for client d35587f4-e5ab-4390-bbe9-7e499a51fc43. Skipping.
# Merging client: 33cd9949-e566-4bdf-a5a9-9278da8965f0
# Found related data for client: 33cd9949-e566-4bdf-a5a9-9278da8965f0
# Client 33cd9949-e566-4bdf-a5a9-9278da8965f0 has 0 contracts
# No contracts found for client 33cd9949-e566-4bdf-a5a9-9278da8965f0. Skipping.
# Merging client: 3c3d80e9-b4c0-4828-9816-aceee59a7390
# Found related data for client: 3c3d80e9-b4c0-4828-9816-aceee59a7390
# Client 3c3d80e9-b4c0-4828-9816-aceee59a7390 has 1 contracts
# Found contract 53c8a394-00bf-4979-8e69-45ec21a5417c for client 3c3d80e9-b4c0-4828-9816-aceee59a7390
# Found 0 policies for contract 53c8a394-00bf-4979-8e69-45ec21a5417c
# Merging client: 6fab0bd3-b630-4145-983b-f44aac6771e7
# Found related data for client: 6fab0bd3-b630-4145-983b-f44aac6771e7
# Client 6fab0bd3-b630-4145-983b-f44aac6771e7 has 0 contracts
# No contracts found for client 6fab0bd3-b630-4145-983b-f44aac6771e7. Skipping.
# Merging client: 0b3bdb58-bf27-419d-8ab4-c623bf7294f9
# Found related data for client: 0b3bdb58-bf27-419d-8ab4-c623bf7294f9
# Client 0b3bdb58-bf27-419d-8ab4-c623bf7294f9 has 0 contracts
# No contracts found for client 0b3bdb58-bf27-419d-8ab4-c623bf7294f9. Skipping.
# Merging client: c9f9ea97-4af8-463a-82d9-ebbca89328e6
# Found related data for client: c9f9ea97-4af8-463a-82d9-ebbca89328e6
# Client c9f9ea97-4af8-463a-82d9-ebbca89328e6 has 0 contracts
# No contracts found for client c9f9ea97-4af8-463a-82d9-ebbca89328e6. Skipping.
# Merging client: b6e9e133-7b8b-4bc3-bce6-1bede0647c30
# Found related data for client: b6e9e133-7b8b-4bc3-bce6-1bede0647c30
# Client b6e9e133-7b8b-4bc3-bce6-1bede0647c30 has 0 contracts
# No contracts found for client b6e9e133-7b8b-4bc3-bce6-1bede0647c30. Skipping.
# Merging client: 50580fc6-2f38-4c4f-88ba-41356a77f4be
# Found related data for client: 50580fc6-2f38-4c4f-88ba-41356a77f4be
# Client 50580fc6-2f38-4c4f-88ba-41356a77f4be has 0 contracts
# No contracts found for client 50580fc6-2f38-4c4f-88ba-41356a77f4be. Skipping.
# Merging client: 7c7cf61b-6dda-49ff-ae19-4360cb3ffde8
# Found related data for client: 7c7cf61b-6dda-49ff-ae19-4360cb3ffde8
# Client 7c7cf61b-6dda-49ff-ae19-4360cb3ffde8 has 1 contracts
# Found contract 05dba90b-c30b-4b6f-9e9a-21cce7cefc00 for client 7c7cf61b-6dda-49ff-ae19-4360cb3ffde8
# Found 0 policies for contract 05dba90b-c30b-4b6f-9e9a-21cce7cefc00
# CSV file 'merged_cassandra.csv' has been created successfully with 15 rows!
